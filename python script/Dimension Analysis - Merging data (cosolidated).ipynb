# %%
import pandas as pd
import matplotlib.pyplot as plt
from ast import literal_eval
from pymongo import MongoClient
import numpy as np
from ast import literal_eval
from bson.objectid import ObjectId

# %%
df_pointer = pd.read_csv('D:/DataWorld/lacritz/data/clarity/pointer_data.csv',index_col=0)
df_click = pd.read_csv('D:/DataWorld/lacritz/data/clarity/click_data.csv',index_col=0)
df_nv = pd.read_csv('D:/DataWorld/lacritz/data/clarity/nv_data.csv',index_col=0)
df_dm = pd.read_csv('D:/DataWorld/lacritz/data/clarity/dm_data.csv',index_col=0)
df_dom = pd.read_csv('D:/DataWorld/lacritz/data/clarity/dom_data.csv',index_col=0)
df_cn = pd.read_csv('D:/DataWorld/lacritz/data/clarity/cn_data.csv',index_col=0)
df_env = pd.read_csv('D:/DataWorld/lacritz/data/clarity/env_data.csv',index_col=0)
df_tm = pd.read_csv('D:/DataWorld/lacritz/data/clarity/tm_data.csv',index_col=0)
df_geo = pd.read_csv('D:/DataWorld/lacritz/data/clarity/geo_data.csv',index_col=0)

tables = ['df_pointer','df_click', 'df_nv', 'df_dm', 'df_dom', 'df_cn', 'df_env' , 'df_tm', 'df_geo']

# %%
# Intial run
def readdata():
    with MongoClient('mongodb://collectionreader:Lacritz12345%23@85.214.144.66:27017/?authSource=dclmdb&readPreference=primary&appname=MongoDB%20Compass&ssl=false') as client:
        filter={}

        result = client['testdb']['A01000_collection'].find(
          filter=filter
        )

    df = pd.DataFrame()

    for i in result:
        df = df.append(i, ignore_index=True)
    
    return df

df = readdata()

# %%
print(f'Dimension:      {df_dm.shape},\nDOM:            {df_dom.shape},\
      \nClick:          {df_click.shape}, \nConnection:     { df_cn.shape},\
      \nPointer:        { df_pointer.shape},\nNavigation:     {df_nv.shape},\
      \nEnvelope:       { df_env.shape},\nTimestamp:      {df_tm.shape}, \nMainDF:         { df.shape}')
# Out:
# Dimension:      (787, 13),
# DOM:            (104523, 12),
# Click:          (825, 23),
# Connection:     (795, 9),
# Pointer:        (13979, 7),
# Navigation:     (787, 20),
# Envelope:       (787, 11),
# Timestamp:      (787, 4),
# MainDF:         (787, 26)

# %% [markdown]
# ## Merging
# - Merging all except pointer and dom

# %%
tmp = pd.merge(df_nv,df_env, left_on='_id', right_on='_id', how = 'outer')

# %%
if sum(np.where(tmp.session_id_x==tmp.session_id_y, 0,1)) == 0:
    tmp.drop(columns=['session_id_y'], inplace=True)
    tmp.rename(columns={'session_id_x':'session_id'})
else:
    print('Session Ids are mismatching in both table')

# %%
df_merged = pd.DataFrame(df_env._id, columns=['_id'])

for tname in tables:
    if tname not in ['df_pointer', 'df_dom']:
        df_merged = pd.merge(eval(tname),df_merged, left_on='_id', right_on='_id', how = 'outer')
        if 'session_id_x' in df_merged.columns:
            #print(df_merged.columns)
            if sum(np.where(df_merged.session_id_x==df_merged.session_id_y, 0,1)) == 0:
                df_merged.drop(columns=['session_id_y'], inplace=True)
                df_merged.rename(columns={'session_id_x':'session_id'}, inplace=True)
                #print(df_merged.columns)

            else:
                print('Session Ids are mismatching in both table')

# %%
df_merged.shape
# Out:
# (833, 75)

# %%
df_merged[df_merged.session_id=='11h19hg']
# Out:
#                           _id        geo_city      geo_region geo_country  \
# 3    605f7322a0423e1ec4b8c618  Mount Pleasant  South Carolina          US
# 26   605fba59093f62234a7b02bf  Mount Pleasant  South Carolina          US
# 27   606012a8093f62234a7b02c0  Mount Pleasant  South Carolina          US
# 28   60602602093f62234a7b02c1  Mount Pleasant  South Carolina          US
# 29   606055d7093f62234a7b02c2  Mount Pleasant  South Carolina          US
# 30   6060a376093f62234a7b02c3  Mount Pleasant  South Carolina          US
# 31   6060d84a093f62234a7b02c4  Mount Pleasant  South Carolina          US
# 32   6060dc93093f62234a7b02c5  Mount Pleasant  South Carolina          US
# 33   6060e618093f62234a7b02c6  Mount Pleasant  South Carolina          US
# 34   60610851093f62234a7b02c7  Mount Pleasant  South Carolina          US
# 35   60612c2f093f62234a7b02c8  Mount Pleasant  South Carolina          US
# 36   60615e60093f62234a7b02c9      Des Moines      Washington          US
# 37   6061dffc093f62234a7b02ca      Des Moines      Washington          US
# 38   6061e3ce093f62234a7b02cb      Des Moines      Washington          US
# 39   6062244c093f62234a7b02cc      Des Moines      Washington          US
# 40   60622b69093f62234a7b02cd      Des Moines      Washington          US
# 41   60623719093f62234a7b02ce      Des Moines      Washington          US
# 42   60629c8e093f62234a7b02cf         Ashburn        Virginia          US
# 43   6062b1e5093f62234a7b02d0         Ashburn        Virginia          US
# 224  606947eea863d0200fd120b9  Mount Pleasant  South Carolina          US
# 279  6069aee6a863d0200fd120ef  Mount Pleasant  South Carolina          US
# 368  6069cffaa863d0200fd12141  Mount Pleasant  South Carolina          US
# 369  6069d263a863d0200fd12142  Mount Pleasant  South Carolina          US
# 411  606a9071a863d0200fd1216b  Mount Pleasant  South Carolina          US
# 412  606a9074a863d0200fd1216c  Mount Pleasant  South Carolina          US
# 493  606adf2ca863d0200fd121bb  Mount Pleasant  South Carolina          US
# 494  606adfa1a863d0200fd121bc  Mount Pleasant  South Carolina          US
# 540  606aedd5a863d0200fd121ea  Mount Pleasant  South Carolina          US
# 675  606dddad670cf020e4a4aaac  Mount Pleasant  South Carolina          US
# 676  606dde94670cf020e4a4aaad  Mount Pleasant  South Carolina          US
# 677  606de0d0670cf020e4a4aaae  Mount Pleasant  South Carolina          US
# 678  606de30f670cf020e4a4aaaf  Mount Pleasant  South Carolina          US
# 679  606de53f670cf020e4a4aab0  Mount Pleasant  South Carolina          US
# 680  606de774670cf020e4a4aab1  Mount Pleasant  South Carolina          US
# 816  6071436b18741e3e8e161890             NaN             NaN         NaN
# 817  6071b2ee18741e3e8e161891             NaN             NaN         NaN
# 830  6072097118741e3e8e16189e             NaN             NaN         NaN
# 831  60720b1918741e3e8e16189f             NaN             NaN         NaN
# 832  60720b9018741e3e8e1618a0             NaN             NaN         NaN
#
#                geo_loc             geo_org session_id     tm_date  \
# 3     32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-03-27
# 26    32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-03-28
# 27    32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-03-28
# 28    32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-03-28
# 29    32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-03-28
# 30    32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-03-28
# 31    32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-03-28
# 32    32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-03-28
# 33    32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-03-28
# 34    32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-03-29
# 35    32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-03-29
# 36   47.4018,-122.3243  AS15169 Google LLC    11h19hg  2021-03-29
# 37   47.4018,-122.3243  AS15169 Google LLC    11h19hg  2021-03-29
# 38   47.4018,-122.3243  AS15169 Google LLC    11h19hg  2021-03-29
# 39   47.4018,-122.3243  AS15169 Google LLC    11h19hg  2021-03-29
# 40   47.4018,-122.3243  AS15169 Google LLC    11h19hg  2021-03-29
# 41   47.4018,-122.3243  AS15169 Google LLC    11h19hg  2021-03-29
# 42    39.0437,-77.4875  AS15169 Google LLC    11h19hg  2021-03-30
# 43    39.0437,-77.4875  AS15169 Google LLC    11h19hg  2021-03-30
# 224   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-04
# 279   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-04
# 368   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-04
# 369   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-04
# 411   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-05
# 412   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-05
# 493   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-05
# 494   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-05
# 540   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-05
# 675   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-07
# 676   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-07
# 677   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-07
# 678   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-07
# 679   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-07
# 680   32.7941,-79.8626  AS15169 Google LLC    11h19hg  2021-04-07
# 816                NaN                 NaN    11h19hg  2021-04-10
# 817                NaN                 NaN    11h19hg  2021-04-10
# 830                NaN                 NaN    11h19hg  2021-04-10
# 831                NaN                 NaN    11h19hg  2021-04-10
# 832                NaN                 NaN    11h19hg  2021-04-10
#
#              tm_time env_version  ...  click_link  click_hash  click_region  \
# 3    19:02:10.807000       0.6.8  ...         NaN         NaN           NaN
# 26   00:06:01.260000       0.6.8  ...         NaN         NaN           NaN
# 27   07:22:48.754000       0.6.8  ...         NaN         NaN           NaN
# 28   08:45:22.885000       0.6.8  ...         NaN         NaN           NaN
# 29   12:09:27.074000       0.6.8  ...         NaN         NaN           NaN
# 30   17:40:38.694000       0.6.8  ...         NaN         NaN           NaN
# 31   21:26:02.577000       0.6.8  ...         NaN         NaN           NaN
# 32   21:44:19.091000       0.6.8  ...         NaN         NaN           NaN
# 33   22:24:56.368000       0.6.8  ...         NaN         NaN           NaN
# 34   00:50:57.106000       0.6.8  ...         NaN         NaN           NaN
# 35   03:23:59.548000       0.6.8  ...         NaN         NaN           NaN
# 36   06:58:08.307000       0.6.8  ...         NaN         NaN           NaN
# 37   16:11:08.254000       0.6.8  ...         NaN         NaN           NaN
# 38   16:27:26.891000       0.6.8  ...         NaN         NaN           NaN
# 39   21:02:36.754000       0.6.8  ...         NaN         NaN           NaN
# 40   21:32:57.492000       0.6.8  ...         NaN         NaN           NaN
# 41   22:22:49.726000       0.6.8  ...         NaN         NaN           NaN
# 42   05:35:42.637000       0.6.8  ...         NaN         NaN           NaN
# 43   07:06:45.356000       0.6.8  ...         NaN         NaN           NaN
# 224  07:00:30.060000       0.6.8  ...         NaN         NaN           NaN
# 279  14:19:50.089000       0.6.8  ...         NaN         NaN           NaN
# 368  16:40:58.199000       0.6.8  ...         NaN         NaN           NaN
# 369  16:51:15.050000       0.6.8  ...         NaN         NaN           NaN
# 411  06:22:09.156000       0.6.8  ...         NaN         NaN           NaN
# 412  06:22:12.516000       0.6.8  ...         NaN         NaN           NaN
# 493         11:58:04       0.6.8  ...         NaN         NaN           NaN
# 494  12:00:01.036000       0.6.8  ...         NaN         NaN           NaN
# 540  13:00:37.911000       0.6.8  ...         NaN         NaN           NaN
# 675  18:28:29.969000       0.6.8  ...         NaN         NaN           NaN
# 676  18:32:20.802000       0.6.8  ...         NaN         NaN           NaN
# 677  18:41:52.713000       0.6.8  ...         NaN         NaN           NaN
# 678  18:51:27.149000       0.6.8  ...         NaN         NaN           NaN
# 679  19:00:47.421000       0.6.8  ...         NaN         NaN           NaN
# 680  19:10:12.216000       0.6.8  ...         NaN         NaN           NaN
# 816  08:19:23.788000       0.6.8  ...         NaN         NaN           NaN
# 817  16:15:10.652000       0.6.8  ...         NaN         NaN           NaN
# 830  22:24:17.038000      0.6.10  ...         NaN         NaN           NaN
# 831  22:31:21.556000      0.6.10  ...         NaN         NaN           NaN
# 832  22:33:20.577000       0.6.8  ...         NaN         NaN           NaN
#
#     click_data_button click_data_context  click_data_hash  click_data_link  \
# 3                 NaN                NaN              NaN              NaN
# 26                NaN                NaN              NaN              NaN
# 27                NaN                NaN              NaN              NaN
# 28                NaN                NaN              NaN              NaN
# 29                NaN                NaN              NaN              NaN
# 30                NaN                NaN              NaN              NaN
# 31                NaN                NaN              NaN              NaN
# 32                NaN                NaN              NaN              NaN
# 33                NaN                NaN              NaN              NaN
# 34                NaN                NaN              NaN              NaN
# 35                NaN                NaN              NaN              NaN
# 36                NaN                NaN              NaN              NaN
# 37                NaN                NaN              NaN              NaN
# 38                NaN                NaN              NaN              NaN
# 39                NaN                NaN              NaN              NaN
# 40                NaN                NaN              NaN              NaN
# 41                NaN                NaN              NaN              NaN
# 42                NaN                NaN              NaN              NaN
# 43                NaN                NaN              NaN              NaN
# 224               NaN                NaN              NaN              NaN
# 279               NaN                NaN              NaN              NaN
# 368               NaN                NaN              NaN              NaN
# 369               NaN                NaN              NaN              NaN
# 411               NaN                NaN              NaN              NaN
# 412               NaN                NaN              NaN              NaN
# 493               NaN                NaN              NaN              NaN
# 494               NaN                NaN              NaN              NaN
# 540               NaN                NaN              NaN              NaN
# 675               NaN                NaN              NaN              NaN
# 676               NaN                NaN              NaN              NaN
# 677               NaN                NaN              NaN              NaN
# 678               NaN                NaN              NaN              NaN
# 679               NaN                NaN              NaN              NaN
# 680               NaN                NaN              NaN              NaN
# 816               NaN                NaN              NaN              NaN
# 817               NaN                NaN              NaN              NaN
# 830               NaN                NaN              NaN              NaN
# 831               NaN                NaN              NaN              NaN
# 832               NaN                NaN              NaN              NaN
#
#      click_data_reaction  click_data_region  click_data_text
# 3                    NaN                NaN              NaN
# 26                   NaN                NaN              NaN
# 27                   NaN                NaN              NaN
# 28                   NaN                NaN              NaN
# 29                   NaN                NaN              NaN
# 30                   NaN                NaN              NaN
# 31                   NaN                NaN              NaN
# 32                   NaN                NaN              NaN
# 33                   NaN                NaN              NaN
# 34                   NaN                NaN              NaN
# 35                   NaN                NaN              NaN
# 36                   NaN                NaN              NaN
# 37                   NaN                NaN              NaN
# 38                   NaN                NaN              NaN
# 39                   NaN                NaN              NaN
# 40                   NaN                NaN              NaN
# 41                   NaN                NaN              NaN
# 42                   NaN                NaN              NaN
# 43                   NaN                NaN              NaN
# 224                  NaN                NaN              NaN
# 279                  NaN                NaN              NaN
# 368                  NaN                NaN              NaN
# 369                  NaN                NaN              NaN
# 411                  NaN                NaN              NaN
# 412                  NaN                NaN              NaN
# 493                  NaN                NaN              NaN
# 494                  NaN                NaN              NaN
# 540                  NaN                NaN              NaN
# 675                  NaN                NaN              NaN
# 676                  NaN                NaN              NaN
# 677                  NaN                NaN              NaN
# 678                  NaN                NaN              NaN
# 679                  NaN                NaN              NaN
# 680                  NaN                NaN              NaN
# 816                  NaN                NaN              NaN
# 817                  NaN                NaN              NaN
# 830                  NaN                NaN              NaN
# 831                  NaN                NaN              NaN
# 832                  NaN                NaN              NaN
#
# [39 rows x 75 columns]

# %%
df_dom[df_dom['_id']=='60720b9018741e3e8e1618a0']
# Out:
#        session_id  dom_time  dom_event  dom_data_id  dom_data_parent  \
# 108168    11h19hg       NaN        NaN          NaN              NaN
#
#         dom_data_previous dom_data_tag  dom_data_position dom_data_selector  \
# 108168                NaN          NaN                NaN               NaN
#
#        dom_data_hash dom_data_attributes                       _id
# 108168           NaN                 NaN  60720b9018741e3e8e1618a0

# %%
df_dom._id.value_counts()
# Out:
# 6069b092a863d0200fd120f1    1623
# 60687d5e5aee672f9c9b692a    1622
# 6070194918741e3e8e161885    1621
# 606880565aee672f9c9b6953    1621
# 6069bfa7a863d0200fd12126    1621
#                             ...
# 606adbfaa863d0200fd121ac       1
# 60698b30a863d0200fd120e9       1
# 606dacdf670cf020e4a4aa68       1
# 606acf94a863d0200fd12196       1
# 606db3d5670cf020e4a4aa8a       1
# Name: _id, Length: 787, dtype: int64

# %%
df_merged.to_csv('D:\DataWorld\lacritz\data\clarity\df_merged.csv')
