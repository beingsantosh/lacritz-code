# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

from pymongo import MongoClient

# %% [markdown]
# ## Intial run

# %%
# Intial run
def readdata():
    client = MongoClient('mongodb://collectionreader:Lacritz12345%23@85.214.144.66:27017/?authSource=dclmdb&readPreference=primary&appname=MongoDB%20Compass&ssl=false')
    filter={}

    result = client['testdb']['A01000_collection'].find(
      filter=filter
    )

    df = pd.DataFrame()

    for i in result:
        df = df.append(i, ignore_index=True)
    
    return df

# %% [markdown]
# #   Execute one time to set the dataframe for comparison

# %%
    # run only first time
df_A01000 = readdata()
df_updated = df_A01000.copy()
df_i = df_updated.ip.str.lstrip(':f').value_counts()

df_ip = pd.DataFrame(index=df_i.index,data=df_i.values, columns=['Count'])

df_ip['Update'] = '-'

# %% [markdown]
# ### df_geo

# %%
def ipInfo(addr=''):
    from urllib.request import urlopen
    from json import load
    if addr == '':
        url = 'https://ipinfo.io/json'
    else:
        url = 'https://ipinfo.io/' + addr + '/json'
    res = urlopen(url)
    #response from url(if res==None then check connection)
    data = load(res)
    #will load the json response into data
    return data

# %%
df_geo = pd.DataFrame(df_ip.index, columns=['IP'])

df_geo['ipinfo'] = df_geo.IP.apply(lambda x:ipInfo(x))

df_geo['city']= df_geo['ipinfo'].apply(lambda x: x.get('city'))
df_geo['region']= df_geo['ipinfo'].apply(lambda x: x.get('region'))
df_geo['country']= df_geo['ipinfo'].apply(lambda x: x.get('country'))
df_geo['location']= df_geo['ipinfo'].apply(lambda x: x.get('loc'))
df_geo['Connection']= df_geo['ipinfo'].apply(lambda x: x.get('org'))
df_geo.drop(columns=['ipinfo'], inplace=True)

df_geo.set_index('IP', inplace=True)
df_geo
# Out:
#                              city                  region country  \
# IP
# 178.200.236.10               Bonn  North Rhine-Westphalia      DE
# 95.223.182.163               Bonn  North Rhine-Westphalia      DE
# 95.223.182.98                Bonn  North Rhine-Westphalia      DE
# 103.77.37.91           Vijayawada          Andhra Pradesh      IN
# 46.128.196.219  Frankfurt am Main                   Hesse      DE
# 49.207.214.61           Bengaluru               Karnataka      IN
# 49.207.214.25           Bengaluru               Karnataka      IN
# 103.77.37.48            Hyderabad               Telangana      IN
# 94.134.92.219            Nürnberg                 Bavaria      DE
# 103.77.37.40            Hyderabad               Telangana      IN
# 49.207.212.248          Bengaluru               Karnataka      IN
# 66.249.70.56       Mount Pleasant          South Carolina      US
# 196.15.23.13            Bengaluru               Karnataka      IN
# 66.249.70.58       Mount Pleasant          South Carolina      US
# 66.249.70.60       Mount Pleasant          South Carolina      US
# 127.0.0.1                    None                    None    None
# 66.249.68.50           Des Moines              Washington      US
# 66.249.68.52           Des Moines              Washington      US
# 196.15.23.6             Bengaluru               Karnataka      IN
# 66.249.68.54           Des Moines              Washington      US
# 66.249.66.92              Ashburn                Virginia      US
# 66.249.66.94              Ashburn                Virginia      US
#
#                          location  \
# IP
# 178.200.236.10     50.7344,7.0955
# 95.223.182.163     50.7344,7.0955
# 95.223.182.98      50.7344,7.0955
# 103.77.37.91      16.5074,80.6466
# 46.128.196.219     50.1155,8.6842
# 49.207.214.61     12.9719,77.5937
# 49.207.214.25     12.9719,77.5937
# 103.77.37.48      17.3840,78.4564
# 94.134.92.219     49.4542,11.0775
# 103.77.37.40      17.3840,78.4564
# 49.207.212.248    12.9719,77.5937
# 66.249.70.56     32.7941,-79.8626
# 196.15.23.13      12.9719,77.5937
# 66.249.70.58     32.7941,-79.8626
# 66.249.70.60     32.7941,-79.8626
# 127.0.0.1                    None
# 66.249.68.50    47.4018,-122.3243
# 66.249.68.52    47.4018,-122.3243
# 196.15.23.6       12.9719,77.5937
# 66.249.68.54    47.4018,-122.3243
# 66.249.66.92     39.0437,-77.4875
# 66.249.66.94     39.0437,-77.4875
#
#                                                        Connection
# IP
# 178.200.236.10                               AS3209 Vodafone GmbH
# 95.223.182.163                               AS3209 Vodafone GmbH
# 95.223.182.98                                AS3209 Vodafone GmbH
# 103.77.37.91             AS24186 RailTel Corporation of India Ltd
# 46.128.196.219                           AS35244 Tele Columbus AG
# 49.207.214.61   AS24309 Atria Convergence Technologies Pvt. Lt...
# 49.207.214.25   AS24309 Atria Convergence Technologies Pvt. Lt...
# 103.77.37.48             AS24186 RailTel Corporation of India Ltd
# 94.134.92.219                AS8881 1&1 Versatel Deutschland GmbH
# 103.77.37.40             AS24186 RailTel Corporation of India Ltd
# 49.207.212.248  AS24309 Atria Convergence Technologies Pvt. Lt...
# 66.249.70.56                                   AS15169 Google LLC
# 196.15.23.13            AS38538 Oracle India Developement Centre.
# 66.249.70.58                                   AS15169 Google LLC
# 66.249.70.60                                   AS15169 Google LLC
# 127.0.0.1                                                    None
# 66.249.68.50                                   AS15169 Google LLC
# 66.249.68.52                                   AS15169 Google LLC
# 196.15.23.6             AS38538 Oracle India Developement Centre.
# 66.249.68.54                                   AS15169 Google LLC
# 66.249.66.92                                   AS15169 Google LLC
# 66.249.66.94                                   AS15169 Google LLC

# %%
df_A01000.shape
# Out:
# (524, 25)

# %% [markdown]
# ### Check update if someone has accessed

# %%
df_updated = readdata()
temp= df_updated.ip.str.lstrip(':f').value_counts()
temp.rename("NewCount", inplace=True)

if 'Count' in df_ip:
    df_ip.rename({'Count':'OldCount'}, axis=1, inplace=True)
    
if not 'NewCount' in df_ip:
    df_ip['NewCount'] = 'NA'

for col in df_ip.columns:
    if not col in ['OldCount',  'NewCount','Update']:
        df_ip.drop(columns=[col],inplace=True)
        
df_ip.columns = ['OldCount',  'NewCount','Update']

update_ip = []

for label, content in temp.iteritems(): 
    if label in df_ip.index:
        #print(label)
        if df_ip.loc[label]['OldCount'] ==  temp[label]:
            #repeat
            df_ip.loc[label] = [df_ip.loc[label]['OldCount'],df_ip.loc[label]['NewCount'],'NaN']
            
        else:
            #update
            df_ip.loc[label] = [df_ip.loc[label]['OldCount'],df_ip.loc[label]['NewCount'], temp[label] - (df_ip.loc[label]['OldCount'] if df_ip.loc[label]['OldCount']!='NA' else 0)]
            update_ip.append(label)
    else:
        df_ip.loc[label] =  ['NA','NA',temp[label]]
        # new ip

#temp = pd.DataFrame(temp)
df_ip.drop(columns=['NewCount'],inplace=True)
df_ip = pd.concat( [df_ip, temp],axis=1)
df_ip = df_ip[['OldCount',  'NewCount','Update']]
df_ip = pd.concat([df_ip,df_geo.city], axis=1)

print (f"Before : {df_ip['OldCount'].sum()} \n After: {temp.sum()}")

for j,ip_ in enumerate(update_ip):
    print ( f"{j+1}. User is from : {df_geo.loc[ip_]['city']},{df_geo.loc[ip_]['country']}, {df_geo.loc[ip_]['region']}")
    
df_ip
# Out:
# Before : 524
#  After: 524
#                 OldCount  NewCount Update               city
# IP
# 178.200.236.10       121       121    NaN               Bonn
# 95.223.182.163        91        91    NaN               Bonn
# 95.223.182.98         80        80    NaN               Bonn
# 103.77.37.91          45        45    NaN         Vijayawada
# 46.128.196.219        30        30    NaN  Frankfurt am Main
# 49.207.214.61         26        26    NaN          Bengaluru
# 49.207.214.25         23        23    NaN          Bengaluru
# 103.77.37.48          22        22    NaN          Hyderabad
# 94.134.92.219         17        17    NaN           Nürnberg
# 103.77.37.40          15        15    NaN          Hyderabad
# 49.207.212.248        14        14    NaN          Bengaluru
# 66.249.70.56           9         9    NaN     Mount Pleasant
# 196.15.23.13           7         7    NaN          Bengaluru
# 66.249.70.58           7         7    NaN     Mount Pleasant
# 66.249.70.60           4         4    NaN     Mount Pleasant
# 127.0.0.1              3         3    NaN               None
# 66.249.68.50           2         2    NaN         Des Moines
# 66.249.68.52           2         2    NaN         Des Moines
# 196.15.23.6            2         2    NaN          Bengaluru
# 66.249.68.54           2         2    NaN         Des Moines
# 66.249.66.92           1         1    NaN            Ashburn
# 66.249.66.94           1         1    NaN            Ashburn

# %%
plt.figure(figsize=(19,6))

a = sns.countplot(x= df_updated.ip, orient='h')
b= plt.xticks(rotation=45)

# %%
a=  df_A01000[197:]

# %% [markdown]
# ### Connection

# %%
a.connection.iloc[3]
# Out:
# [{'time': 35,
#   'event': 30,
#   'data': {'downlink': 10, 'rtt': 50, 'saveData': 0, 'type': '4g'}}]

# %% [markdown]
# ### Dimension

# %%
a.dimension.iloc[3]
# Out:
# [{'time': 3656,
#   'event': 1,
#   'data': {'0': ['Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36'],
#    '1': ['https://mytravelexp.com/'],
#    '2': ['https://mytravelexp.com/category/budget-travel/'],
#    '3': ['Home - My Travel Exp'],
#    '4': ['mytravelexp.com',
#     'fonts.googleapis.com',
#     'www.google-analytics.com',
#     '85.214.144.66',
#     'fonts.gstatic.com',
#     'maps.google.com',
#     'stats.g.doubleclick.net',
#     'www.clarity.ms',
#     'c.clarity.ms'],
#    '9': ['en-US']}}]

# %% [markdown]
# ### Doc

# %%
a.doc.iloc[3]
# Out:
# [{'time': 4, 'event': 8, 'data': {'width': 1519, 'height': 4142}}]

# %% [markdown]
# ### Envelope

# %%
a.envelope.iloc[0],a.envelope.iloc[1],a.envelope.iloc[2],a.envelope.iloc[3]
# Out:
# ({'version': '0.6.10',
#   'sequence': 2,
#   'start': 3190,
#   'duration': 61007,
#   'projectId': 'A01000',
#   'userId': 'j87jtf',
#   'sessionId': '111j3jy',
#   'pageNum': 3,
#   'upload': 0,
#   'end': 0},
#  {'version': '0.6.10',
#   'sequence': 3,
#   'start': 64197,
#   'duration': 54262,
#   'projectId': 'A01000',
#   'userId': 'j87jtf',
#   'sessionId': '111j3jy',
#   'pageNum': 3,
#   'upload': 0,
#   'end': 0},
#  {'version': '0.6.10',
#   'sequence': 4,
#   'start': 118459,
#   'duration': 729,
#   'projectId': 'A01000',
#   'userId': 'j87jtf',
#   'sessionId': '111j3jy',
#   'pageNum': 3,
#   'upload': 1,
#   'end': 1},
#  {'version': '0.6.10',
#   'sequence': 1,
#   'start': 0,
#   'duration': 3656,
#   'projectId': 'A01000',
#   'userId': 'j87jtf',
#   'sessionId': '111j3jy',
#   'pageNum': 4,
#   'upload': 0,
#   'end': 0})

# %% [markdown]
# ### Metric

# %%
a.metric.iloc[0],a.metric.iloc[1],a.metric.iloc[2],a.metric.iloc[3]
# Out:
# ([{'time': 64197, 'event': 0, 'data': {'1': 1, '2': 52533, '4': 6}}],
#  [{'time': 118459,
#    'event': 0,
#    'data': {'2': 3725, '3': 1, '4': 29, '5': 2, '10': 3}}],
#  [{'time': 119188, 'event': 0, 'data': {'2': 194, '4': 2}}],
#  [{'time': 3656,
#    'event': 0,
#    'data': {'0': 1617461269602.0,
#     '1': 0,
#     '2': 1466,
#     '3': 55,
#     '4': 69,
#     '5': 6,
#     '6': 31,
#     '7': 3,
#     '8': 2120,
#     '9': 0,
#     '10': 51,
#     '14': 1536,
#     '15': 864,
#     '16': 24}}])

# %% [markdown]
# ### Navigation

# %%
a.navigation.iloc[3]
# Out:
# [{'time': 997,
#   'event': 29,
#   'data': {'fetchStart': 4,
#    'connectStart': 83,
#    'connectEnd': 131,
#    'requestStart': 85,
#    'responseStart': 1754,
#    'responseEnd': 1760,
#    'domInteractive': 1933,
#    'domComplete': 3103,
#    'loadEventStart': 3103,
#    'loadEventEnd': 3104,
#    'redirectCount': 0,
#    'size': 24014,
#    'type': 'navigate',
#    'protocol': 'h3-Q050',
#    'encodedSize': 23723,
#    'decodedSize': 103477}}]

# %% [markdown]
# ### Pointer

# %%
a.pointer.iloc[1]
# same with a.pointera.iloc[2],a.pointer.iloc[3]
# Out:
# [{'time': 115865, 'event': 12, 'data': {'target': 455, 'x': 1088, 'y': 2}},
#  {'time': 115892, 'event': 12, 'data': {'target': 455, 'x': 1088, 'y': 19}},
#  {'time': 115909, 'event': 12, 'data': {'target': 455, 'x': 1088, 'y': 29}},
#  {'time': 115925, 'event': 12, 'data': {'target': 455, 'x': 1080, 'y': 50}},
#  {'time': 115943, 'event': 12, 'data': {'target': 150, 'x': 1056, 'y': 94}},
#  {'time': 115959, 'event': 12, 'data': {'target': 143, 'x': 1032, 'y': 122}},
#  {'time': 115976, 'event': 12, 'data': {'target': 143, 'x': 1003, 'y': 150}},
#  {'time': 115993, 'event': 12, 'data': {'target': 165, 'x': 981, 'y': 168}},
#  {'time': 116009, 'event': 12, 'data': {'target': 165, 'x': 960, 'y': 181}},
#  {'time': 116026, 'event': 12, 'data': {'target': 165, 'x': 941, 'y': 190}},
#  {'time': 116042, 'event': 12, 'data': {'target': 165, 'x': 928, 'y': 197}},
#  {'time': 116059, 'event': 12, 'data': {'target': 165, 'x': 916, 'y': 202}},
#  {'time': 116076, 'event': 12, 'data': {'target': 165, 'x': 904, 'y': 205}},
#  {'time': 116092, 'event': 12, 'data': {'target': 165, 'x': 893, 'y': 209}},
#  {'time': 116109, 'event': 12, 'data': {'target': 165, 'x': 880, 'y': 211}},
#  {'time': 116126, 'event': 12, 'data': {'target': 165, 'x': 855, 'y': 214}},
#  {'time': 116142, 'event': 12, 'data': {'target': 165, 'x': 843, 'y': 216}},
#  {'time': 116159, 'event': 12, 'data': {'target': 165, 'x': 794, 'y': 224}},
#  {'time': 116176, 'event': 12, 'data': {'target': 181, 'x': 752, 'y': 230}},
#  {'time': 116192, 'event': 12, 'data': {'target': 181, 'x': 704, 'y': 236}},
#  {'time': 116209, 'event': 12, 'data': {'target': 181, 'x': 652, 'y': 244}},
#  {'time': 116226, 'event': 12, 'data': {'target': 181, 'x': 599, 'y': 244}},
#  {'time': 116243, 'event': 12, 'data': {'target': 181, 'x': 543, 'y': 244}},
#  {'time': 116259, 'event': 12, 'data': {'target': 181, 'x': 496, 'y': 244}},
#  {'time': 116276, 'event': 12, 'data': {'target': 181, 'x': 452, 'y': 242}},
#  {'time': 116292, 'event': 12, 'data': {'target': 181, 'x': 429, 'y': 234}},
#  {'time': 116309, 'event': 12, 'data': {'target': 181, 'x': 417, 'y': 233}},
#  {'time': 116325, 'event': 12, 'data': {'target': 181, 'x': 415, 'y': 230}},
#  {'time': 116343, 'event': 12, 'data': {'target': 165, 'x': 417, 'y': 221}},
#  {'time': 116359, 'event': 12, 'data': {'target': 165, 'x': 449, 'y': 211}},
#  {'time': 116375, 'event': 12, 'data': {'target': 165, 'x': 494, 'y': 221}},
#  {'time': 116458, 'event': 12, 'data': {'target': 165, 'x': 493, 'y': 224}},
#  {'time': 116480, 'event': 12, 'data': {'target': 181, 'x': 497, 'y': 243}},
#  {'time': 116495, 'event': 12, 'data': {'target': 181, 'x': 488, 'y': 243}},
#  {'time': 116510, 'event': 12, 'data': {'target': 181, 'x': 472, 'y': 241}},
#  {'time': 116525, 'event': 12, 'data': {'target': 181, 'x': 469, 'y': 238}},
#  {'time': 116542, 'event': 12, 'data': {'target': 181, 'x': 472, 'y': 230}},
#  {'time': 116559, 'event': 12, 'data': {'target': 165, 'x': 490, 'y': 221}},
#  {'time': 116575, 'event': 12, 'data': {'target': 165, 'x': 530, 'y': 206}},
#  {'time': 116592, 'event': 12, 'data': {'target': 165, 'x': 577, 'y': 198}},
#  {'time': 116609, 'event': 12, 'data': {'target': 165, 'x': 640, 'y': 194}},
#  {'time': 116626, 'event': 12, 'data': {'target': 165, 'x': 724, 'y': 181}},
#  {'time': 116642, 'event': 12, 'data': {'target': 165, 'x': 808, 'y': 168}},
#  {'time': 116659, 'event': 12, 'data': {'target': 165, 'x': 873, 'y': 158}},
#  {'time': 116676, 'event': 12, 'data': {'target': 143, 'x': 926, 'y': 150}},
#  {'time': 116692, 'event': 12, 'data': {'target': 143, 'x': 956, 'y': 145}},
#  {'time': 116709, 'event': 12, 'data': {'target': 143, 'x': 976, 'y': 138}},
#  {'time': 116726, 'event': 12, 'data': {'target': 143, 'x': 981, 'y': 135}},
#  {'time': 116742, 'event': 12, 'data': {'target': 143, 'x': 984, 'y': 133}},
#  {'time': 116758, 'event': 12, 'data': {'target': 143, 'x': 984, 'y': 129}},
#  {'time': 116775, 'event': 12, 'data': {'target': 143, 'x': 984, 'y': 119}},
#  {'time': 116792, 'event': 12, 'data': {'target': 143, 'x': 984, 'y': 110}},
#  {'time': 116809, 'event': 12, 'data': {'target': 143, 'x': 981, 'y': 102}},
#  {'time': 116826, 'event': 12, 'data': {'target': 150, 'x': 975, 'y': 94}},
#  {'time': 116845, 'event': 12, 'data': {'target': 449, 'x': 963, 'y': 84}},
#  {'time': 116858, 'event': 12, 'data': {'target': 449, 'x': 955, 'y': 79}},
#  {'time': 116877, 'event': 12, 'data': {'target': 449, 'x': 939, 'y': 73}},
#  {'time': 116893, 'event': 12, 'data': {'target': 449, 'x': 924, 'y': 71}},
#  {'time': 116910, 'event': 12, 'data': {'target': 449, 'x': 908, 'y': 70}},
#  {'time': 116926, 'event': 12, 'data': {'target': 449, 'x': 892, 'y': 70}},
#  {'time': 116942, 'event': 12, 'data': {'target': 449, 'x': 879, 'y': 70}},
#  {'time': 116959, 'event': 12, 'data': {'target': 449, 'x': 871, 'y': 70}},
#  {'time': 116977, 'event': 12, 'data': {'target': 448, 'x': 860, 'y': 70}},
#  {'time': 116992, 'event': 12, 'data': {'target': 448, 'x': 859, 'y': 70}},
#  {'time': 117009, 'event': 12, 'data': {'target': 448, 'x': 856, 'y': 70}},
#  {'time': 117025, 'event': 12, 'data': {'target': 448, 'x': 854, 'y': 69}},
#  {'time': 117059, 'event': 12, 'data': {'target': 448, 'x': 854, 'y': 67}},
#  {'time': 117076, 'event': 12, 'data': {'target': 448, 'x': 854, 'y': 66}},
#  {'time': 117092, 'event': 12, 'data': {'target': 448, 'x': 852, 'y': 64}},
#  {'time': 117109, 'event': 12, 'data': {'target': 448, 'x': 852, 'y': 62}},
#  {'time': 117125, 'event': 12, 'data': {'target': 448, 'x': 852, 'y': 61}},
#  {'time': 117142, 'event': 12, 'data': {'target': 448, 'x': 849, 'y': 58}},
#  {'time': 117159, 'event': 12, 'data': {'target': 448, 'x': 848, 'y': 58}},
#  {'time': 117175, 'event': 12, 'data': {'target': 448, 'x': 847, 'y': 56}},
#  {'time': 117192, 'event': 12, 'data': {'target': 448, 'x': 846, 'y': 54}},
#  {'time': 117208, 'event': 12, 'data': {'target': 448, 'x': 844, 'y': 52}},
#  {'time': 117225, 'event': 12, 'data': {'target': 448, 'x': 843, 'y': 51}},
#  {'time': 117242, 'event': 12, 'data': {'target': 448, 'x': 842, 'y': 50}},
#  {'time': 117358, 'event': 13, 'data': {'target': 448, 'x': 842, 'y': 50}},
#  {'time': 117413, 'event': 14, 'data': {'target': 448, 'x': 842, 'y': 50}}]

# %% [markdown]
# ### Resize

# %%
a.resize.iloc[3]
# Out:
# [{'time': 35, 'event': 11, 'data': {'width': 1519, 'height': 731}}]

# %% [markdown]
# ### Timestamp

# %%
a.timestamp
# Out:
# 197    1617461213
# 198    1617461268
# 199    1617461268
# 200    1617461272
# Name: timestamp, dtype: int64

# %% [markdown]
# ### Visibility

# %%
a.visibility.iloc[1]
# Out:
# [{'time': 115446, 'event': 28, 'data': {'visible': 'visible'}}]

# %% [markdown]
# ### Summary

# %%
a.summary.iloc[1]
# Out:
# [{'time': 118459, 'event': 36, 'data': {'6': [[117370, 7]]}}]

# %% [markdown]
# ### Baseline

# %%
a.baseline.iloc[0]
# Out:
# [{'time': 3189,
#   'event': 4,
#   'data': {'visible': 0,
#    'docWidth': 1519,
#    'docHeight': 3075,
#    'screenWidth': 1519,
#    'screenHeight': 731,
#    'scrollX': 0,
#    'scrollY': 0,
#    'pointerX': 1172,
#    'pointerY': 5,
#    'activityTime': 2036}}]

# %% [markdown]
# ### Scroll

# %%
a.scroll.iloc[3]
# Out:
# nan

# %% [markdown]
# ### Click

# %%
a.click.iloc[1]
# Out:
# [{'time': 117414,
#   'event': 9,
#   'data': {'target': 448,
#    'x': 842,
#    'y': 50,
#    'eX': 19660,
#    'eY': 17429,
#    'button': 0,
#    'reaction': 1,
#    'context': 0,
#    'text': 'Home',
#    'link': 'https://mytravelexp.com/',
#    'hash': '1y4fff1gd',
#    'region': None}}]

# %% [markdown]
# ### Ping

# %%
a.ping.iloc[0]
# Out:
# [{'time': 60192, 'event': 25, 'data': {'gap': 60189}}]

# %% [markdown]
# ### Limit

# %%
a.limit
# Out:
# 197    NaN
# 198    NaN
# 199    NaN
# 200    NaN
# Name: limit, dtype: object

# %% [markdown]
# ### Upload

# %%
a.upload
# Out:
# 197    NaN
# 198    NaN
# 199    NaN
# 200    NaN
# Name: upload, dtype: object

# %% [markdown]
# ### Unload

# %%
a.unload.iloc[2]
# Out:
# [{'time': 119188, 'event': 26, 'data': {'name': 'pagehide'}}]

# %% [markdown]
# ### Custom

# %%
a.custom
# Out:
# 197    NaN
# 198    NaN
# 199    NaN
# 200    NaN
# Name: custom, dtype: object

# %% [markdown]
# ### DOM

# %%
a.dom.iloc[0]
# Out:
# [{'time': 3,
#   'event': 5,
#   'data': [{'id': 1,
#     'parent': None,
#     'previous': None,
#     'tag': '*D',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'attributes': {'name': 'html', 'publicId': '', 'systemId': ''}},
#    {'id': 2,
#     'parent': 1,
#     'previous': None,
#     'tag': 'HTML',
#     'position': None,
#     'selector': 'HTML',
#     'hash': 'v6qkchb',
#     'attributes': {'lang': 'en-US'}},
#    {'id': 3,
#     'parent': 2,
#     'previous': None,
#     'tag': 'HEAD',
#     'position': 1,
#     'selector': 'HTML>HEAD:nth-of-type(1)',
#     'hash': '4gf3cl7se',
#     'attributes': {'*B': 'https://mytravelexp.com'}},
#    {'id': 4,
#     'parent': 2,
#     'previous': 3,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n'},
#    {'id': 5,
#     'parent': 2,
#     'previous': 4,
#     'tag': 'BODY',
#     'position': None,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4',
#     'hash': '82zgj0db3',
#     'attributes': {'itemtype': 'https://schema.org/Blog',
#      'itemscope': 'itemscope',
#      'class': 'archive category category-budget-travel category-82 ehf-footer ehf-template-astra ehf-stylesheet-astra ast-desktop ast-separate-container ast-right-sidebar astra-2.5.5 ast-header-custom-item-inside ast-inherit-site-logo-transparent elementor-default elementor-kit-4',
#      'data-elementor-device-mode': 'desktop',
#      'style': ''}},
#    {'id': 6,
#     'parent': 3,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 7,
#     'parent': 3,
#     'previous': 6,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 8,
#     'parent': 3,
#     'previous': 7,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 9,
#     'parent': 3,
#     'previous': 8,
#     'tag': 'LINK',
#     'position': 1,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'profile', 'href': 'https://gmpg.org/xfn/11'}},
#    {'id': 10,
#     'parent': 3,
#     'previous': 9,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\n\t'},
#    {'id': 11,
#     'parent': 3,
#     'previous': 10,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 12,
#     'parent': 3,
#     'previous': 11,
#     'tag': 'TITLE',
#     'position': 1,
#     'selector': None,
#     'hash': None},
#    {'id': 13,
#     'parent': 3,
#     'previous': 12,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 14,
#     'parent': 3,
#     'previous': 13,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 15,
#     'parent': 3,
#     'previous': 14,
#     'tag': 'LINK',
#     'position': 2,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'canonical',
#      'href': 'https://mytravelexp.com/category/budget-travel/'}},
#    {'id': 16,
#     'parent': 3,
#     'previous': 15,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 17,
#     'parent': 3,
#     'previous': 16,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 18,
#     'parent': 3,
#     'previous': 17,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 19,
#     'parent': 3,
#     'previous': 18,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 20,
#     'parent': 3,
#     'previous': 19,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 21,
#     'parent': 3,
#     'previous': 20,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 22,
#     'parent': 3,
#     'previous': 21,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 23,
#     'parent': 3,
#     'previous': 22,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 24,
#     'parent': 3,
#     'previous': 23,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\n'},
#    {'id': 25,
#     'parent': 3,
#     'previous': 24,
#     'tag': 'LINK',
#     'position': 3,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'dns-prefetch', 'href': '//s.w.org'}},
#    {'id': 26,
#     'parent': 3,
#     'previous': 25,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 27,
#     'parent': 3,
#     'previous': 26,
#     'tag': 'LINK',
#     'position': 4,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'alternate',
#      'type': 'application/rss+xml',
#      'href': 'https://mytravelexp.com/feed/'}},
#    {'id': 28,
#     'parent': 3,
#     'previous': 27,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 29,
#     'parent': 3,
#     'previous': 28,
#     'tag': 'LINK',
#     'position': 5,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'alternate',
#      'type': 'application/rss+xml',
#      'href': 'https://mytravelexp.com/comments/feed/'}},
#    {'id': 30,
#     'parent': 3,
#     'previous': 29,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 31,
#     'parent': 3,
#     'previous': 30,
#     'tag': 'LINK',
#     'position': 6,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'alternate',
#      'type': 'application/rss+xml',
#      'href': 'https://mytravelexp.com/category/budget-travel/feed/'}},
#    {'id': 32,
#     'parent': 3,
#     'previous': 31,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 33,
#     'parent': 3,
#     'previous': 32,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 34,
#     'parent': 3,
#     'previous': 33,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 35,
#     'parent': 3,
#     'previous': 34,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t'},
#    {'id': 36,
#     'parent': 3,
#     'previous': 35,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t'},
#    {'id': 37,
#     'parent': 3,
#     'previous': 36,
#     'tag': 'STYLE',
#     'position': 1,
#     'selector': None,
#     'hash': None,
#     'value': 'img.wp-smiley,\nimg.emoji {\n\tdisplay: inline !important;\n\tborder: none !important;\n\tbox-shadow: none !important;\n\theight: 1em !important;\n\twidth: 1em !important;\n\tmargin: 0 .07em !important;\n\tvertical-align: -0.1em !important;\n\tbackground: none !important;\n\tpadding: 0 !important;\n}'},
#    {'id': 38,
#     'parent': 3,
#     'previous': 37,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 39,
#     'parent': 3,
#     'previous': 38,
#     'tag': 'LINK',
#     'position': 7,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'astra-theme-css-css',
#      'href': 'https://mytravelexp.com/wp-content/themes/astra/assets/css/minified/style.min.css?ver=2.5.5',
#      'media': 'all'}},
#    {'id': 40,
#     'parent': 3,
#     'previous': 39,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 41,
#     'parent': 3,
#     'previous': 40,
#     'tag': 'STYLE',
#     'position': 2,
#     'selector': None,
#     'hash': None,
#     'attributes': {'id': 'astra-theme-css-inline-css'},
#     'value': 'html{font-size:93.75%;}a,.page-title{color:#0274be;}a:hover,a:focus{color:#3a3a3a;}body,button,input,select,textarea,.ast-button,.ast-custom-button{font-family:-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Oxygen-Sans,Ubuntu,Cantarell,Helvetica Neue,sans-serif;font-weight:inherit;font-size:15px;font-size:1rem;}blockquote{color:#000000;}.site-title{font-size:35px;font-size:2.3333333333333rem;}.ast-archive-description .ast-archive-title{font-size:40px;font-size:2.6666666666667rem;}.site-header .site-description{font-size:15px;font-size:1rem;}.entry-title{font-size:40px;font-size:2.6666666666667rem;}.comment-reply-title{font-size:24px;font-size:1.6rem;}.ast-comment-list #cancel-comment-reply-link{font-size:15px;font-size:1rem;}h1,.entry-content h1{font-size:40px;font-size:2.6666666666667rem;}h2,.entry-content h2{font-size:30px;font-size:2rem;}h3,.entry-content h3{font-size:25px;font-size:1.6666666666667rem;}h4,.entry-content h4{font-size:20px;font-size:1.3333333333333rem;}h5,.entry-content h5{font-size:18px;font-size:1.2rem;}h6,.entry-content h6{font-size:15px;font-size:1rem;}.ast-single-post .entry-title,.page-title{font-size:30px;font-size:2rem;}#secondary,#secondary button,#secondary input,#secondary select,#secondary textarea{font-size:15px;font-size:1rem;}::selection{background-color:#0274be;color:#ffffff;}body,h1,.entry-title a,.entry-content h1,h2,.entry-content h2,h3,.entry-content h3,h4,.entry-content h4,h5,.entry-content h5,h6,.entry-content h6,.wc-block-grid__product-title{color:#3a3a3a;}.tagcloud a:hover,.tagcloud a:focus,.tagcloud a.current-item{color:#ffffff;border-color:#0274be;background-color:#0274be;}.main-header-menu .menu-link,.ast-header-custom-item a{color:#3a3a3a;}.main-header-menu .menu-item:hover > .menu-link,.main-header-menu .menu-item:hover > .ast-menu-toggle,.main-header-menu .ast-masthead-custom-menu-items a:hover,.main-header-menu .menu-item.focus > .menu-link,.main-header-menu .menu-item.focus > .ast-menu-toggle,.main-header-menu .current-menu-item > .menu-link,.main-header-menu .current-menu-ancestor > .menu-link,.main-header-menu .current-menu-item > .ast-menu-toggle,.main-header-menu .current-menu-ancestor > .ast-menu-toggle{color:#0274be;}input:focus,input[type="text"]:focus,input[type="email"]:focus,input[type="url"]:focus,input[type="password"]:focus,input[type="reset"]:focus,input[type="search"]:focus,textarea:focus{border-color:#0274be;}input[type="radio"]:checked,input[type=reset],input[type="checkbox"]:checked,input[type="checkbox"]:hover:checked,input[type="checkbox"]:focus:checked,input[type=range]::-webkit-slider-thumb{border-color:#0274be;background-color:#0274be;box-shadow:none;}.site-footer a:hover + .post-count,.site-footer a:focus + .post-count{background:#0274be;border-color:#0274be;}.footer-adv .footer-adv-overlay{border-top-style:solid;border-top-color:#7a7a7a;}.ast-comment-meta{line-height:1.666666667;font-size:12px;font-size:0.8rem;}.single .nav-links .nav-previous,.single .nav-links .nav-next,.single .ast-author-details .author-title,.ast-comment-meta{color:#0274be;}.entry-meta,.entry-meta *{line-height:1.45;color:#0274be;}.entry-meta a:hover,.entry-meta a:hover *,.entry-meta a:focus,.entry-meta a:focus *{color:#3a3a3a;}.ast-404-layout-1 .ast-404-text{font-size:200px;font-size:13.333333333333rem;}.widget-title{font-size:21px;font-size:1.4rem;color:#3a3a3a;}#cat option,.secondary .calendar_wrap thead a,.secondary .calendar_wrap thead a:visited{color:#0274be;}.secondary .calendar_wrap #today,.ast-progress-val span{background:#0274be;}.secondary a:hover + .post-count,.secondary a:focus + .post-count{background:#0274be;border-color:#0274be;}.calendar_wrap #today > a{color:#ffffff;}.ast-pagination a,.page-links .page-link,.single .post-navigation a{color:#0274be;}.ast-pagination a:hover,.ast-pagination a:focus,.ast-pagination > span:hover:not(.dots),.ast-pagination > span.current,.page-links > .page-link,.page-links .page-link:hover,.post-navigation a:hover{color ...
#    {'id': 42,
#     'parent': 3,
#     'previous': 41,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 43,
#     'parent': 3,
#     'previous': 42,
#     'tag': 'LINK',
#     'position': 8,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'astra-menu-animation-css',
#      'href': 'https://mytravelexp.com/wp-content/themes/astra/assets/css/minified/menu-animation.min.css?ver=2.5.5',
#      'media': 'all'}},
#    {'id': 44,
#     'parent': 3,
#     'previous': 43,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 45,
#     'parent': 3,
#     'previous': 44,
#     'tag': 'LINK',
#     'position': 9,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'wp-block-library-css',
#      'href': 'https://mytravelexp.com/wp-includes/css/dist/block-library/style.min.css?ver=5.5.3',
#      'media': 'all'}},
#    {'id': 46,
#     'parent': 3,
#     'previous': 45,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 47,
#     'parent': 3,
#     'previous': 46,
#     'tag': 'LINK',
#     'position': 10,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'hfe-style-css',
#      'href': 'https://mytravelexp.com/wp-content/plugins/header-footer-elementor/assets/css/header-footer-elementor.css?ver=1.5.3',
#      'media': 'all'}},
#    {'id': 48,
#     'parent': 3,
#     'previous': 47,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 49,
#     'parent': 3,
#     'previous': 48,
#     'tag': 'LINK',
#     'position': 11,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'elementor-icons-css',
#      'href': 'https://mytravelexp.com/wp-content/plugins/elementor/assets/lib/eicons/css/elementor-icons.min.css?ver=5.9.1',
#      'media': 'all'}},
#    {'id': 50,
#     'parent': 3,
#     'previous': 49,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 51,
#     'parent': 3,
#     'previous': 50,
#     'tag': 'LINK',
#     'position': 12,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'elementor-animations-css',
#      'href': 'https://mytravelexp.com/wp-content/plugins/elementor/assets/lib/animations/animations.min.css?ver=3.0.12',
#      'media': 'all'}},
#    {'id': 52,
#     'parent': 3,
#     'previous': 51,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 53,
#     'parent': 3,
#     'previous': 52,
#     'tag': 'LINK',
#     'position': 13,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'elementor-frontend-legacy-css',
#      'href': 'https://mytravelexp.com/wp-content/plugins/elementor/assets/css/frontend-legacy.min.css?ver=3.0.12',
#      'media': 'all'}},
#    {'id': 54,
#     'parent': 3,
#     'previous': 53,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 55,
#     'parent': 3,
#     'previous': 54,
#     'tag': 'LINK',
#     'position': 14,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'elementor-frontend-css',
#      'href': 'https://mytravelexp.com/wp-content/plugins/elementor/assets/css/frontend.min.css?ver=3.0.12',
#      'media': 'all'}},
#    {'id': 56,
#     'parent': 3,
#     'previous': 55,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 57,
#     'parent': 3,
#     'previous': 56,
#     'tag': 'LINK',
#     'position': 15,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'elementor-post-4-css',
#      'href': 'https://mytravelexp.com/wp-content/uploads/elementor/css/post-4.css?ver=1604406951',
#      'media': 'all'}},
#    {'id': 58,
#     'parent': 3,
#     'previous': 57,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 59,
#     'parent': 3,
#     'previous': 58,
#     'tag': 'LINK',
#     'position': 16,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'font-awesome-5-all-css',
#      'href': 'https://mytravelexp.com/wp-content/plugins/elementor/assets/lib/font-awesome/css/all.min.css?ver=3.0.12',
#      'media': 'all'}},
#    {'id': 60,
#     'parent': 3,
#     'previous': 59,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 61,
#     'parent': 3,
#     'previous': 60,
#     'tag': 'LINK',
#     'position': 17,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'font-awesome-4-shim-css',
#      'href': 'https://mytravelexp.com/wp-content/plugins/elementor/assets/lib/font-awesome/css/v4-shims.min.css?ver=3.0.12',
#      'media': 'all'}},
#    {'id': 62,
#     'parent': 3,
#     'previous': 61,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 63,
#     'parent': 3,
#     'previous': 62,
#     'tag': 'LINK',
#     'position': 18,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'elementor-global-css',
#      'href': 'https://mytravelexp.com/wp-content/uploads/elementor/css/global.css?ver=1604407292',
#      'media': 'all'}},
#    {'id': 64,
#     'parent': 3,
#     'previous': 63,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 65,
#     'parent': 3,
#     'previous': 64,
#     'tag': 'LINK',
#     'position': 19,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'elementor-post-162-css',
#      'href': 'https://mytravelexp.com/wp-content/uploads/elementor/css/post-162.css?ver=1604406952',
#      'media': 'all'}},
#    {'id': 66,
#     'parent': 3,
#     'previous': 65,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 67,
#     'parent': 3,
#     'previous': 66,
#     'tag': 'LINK',
#     'position': 20,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'hfe-widgets-style-css',
#      'href': 'https://mytravelexp.com/wp-content/plugins/header-footer-elementor/inc/widgets-css/frontend.css?ver=1.5.3',
#      'media': 'all'}},
#    {'id': 68,
#     'parent': 3,
#     'previous': 67,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 69,
#     'parent': 3,
#     'previous': 68,
#     'tag': 'LINK',
#     'position': 21,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'jquery-lazyloadxt-spinner-css-css',
#      'href': '//mytravelexp.com/wp-content/plugins/a3-lazy-load/assets/css/jquery.lazyloadxt.spinner.css?ver=5.5.3',
#      'media': 'all'}},
#    {'id': 70,
#     'parent': 3,
#     'previous': 69,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 71,
#     'parent': 3,
#     'previous': 70,
#     'tag': 'LINK',
#     'position': 22,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'google-fonts-1-css',
#      'href': 'https://fonts.googleapis.com/css?family=Roboto%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic%7CRoboto+Slab%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic&ver=5.5.3',
#      'media': 'all'}},
#    {'id': 72,
#     'parent': 3,
#     'previous': 71,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 73,
#     'parent': 3,
#     'previous': 72,
#     'tag': 'LINK',
#     'position': 23,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'elementor-icons-shared-0-css',
#      'href': 'https://mytravelexp.com/wp-content/plugins/elementor/assets/lib/font-awesome/css/fontawesome.min.css?ver=5.12.0',
#      'media': 'all'}},
#    {'id': 74,
#     'parent': 3,
#     'previous': 73,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 75,
#     'parent': 3,
#     'previous': 74,
#     'tag': 'LINK',
#     'position': 24,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'elementor-icons-fa-brands-css',
#      'href': 'https://mytravelexp.com/wp-content/plugins/elementor/assets/lib/font-awesome/css/brands.min.css?ver=5.12.0',
#      'media': 'all'}},
#    {'id': 76,
#     'parent': 3,
#     'previous': 75,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 77,
#     'parent': 3,
#     'previous': 76,
#     'tag': 'LINK',
#     'position': 25,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'elementor-icons-fa-solid-css',
#      'href': 'https://mytravelexp.com/wp-content/plugins/elementor/assets/lib/font-awesome/css/solid.min.css?ver=5.12.0',
#      'media': 'all'}},
#    {'id': 78,
#     'parent': 3,
#     'previous': 77,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 79,
#     'parent': 3,
#     'previous': 78,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 80,
#     'parent': 3,
#     'previous': 79,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 81,
#     'parent': 3,
#     'previous': 80,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 82,
#     'parent': 3,
#     'previous': 81,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 83,
#     'parent': 3,
#     'previous': 82,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 84,
#     'parent': 3,
#     'previous': 83,
#     'tag': 'LINK',
#     'position': 26,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'https://api.w.org/',
#      'href': 'https://mytravelexp.com/wp-json/'}},
#    {'id': 85,
#     'parent': 3,
#     'previous': 84,
#     'tag': 'LINK',
#     'position': 27,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'alternate',
#      'type': 'application/json',
#      'href': 'https://mytravelexp.com/wp-json/wp/v2/categories/82'}},
#    {'id': 86,
#     'parent': 3,
#     'previous': 85,
#     'tag': 'LINK',
#     'position': 28,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'EditURI',
#      'type': 'application/rsd+xml',
#      'href': 'https://mytravelexp.com/xmlrpc.php?rsd'}},
#    {'id': 87,
#     'parent': 3,
#     'previous': 86,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 88,
#     'parent': 3,
#     'previous': 87,
#     'tag': 'LINK',
#     'position': 29,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'wlwmanifest',
#      'type': 'application/wlwmanifest+xml',
#      'href': 'https://mytravelexp.com/wp-includes/wlwmanifest.xml'}},
#    {'id': 89,
#     'parent': 3,
#     'previous': 88,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': ' \n'},
#    {'id': 90,
#     'parent': 3,
#     'previous': 89,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n       '},
#    {'id': 91,
#     'parent': 3,
#     'previous': 90,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n    '},
#    {'id': 92,
#     'parent': 3,
#     'previous': 91,
#     'tag': 'LINK',
#     'position': 30,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'icon',
#      'href': 'https://mytravelexp.com/wp-content/uploads/2020/09/cropped-onlinelogomaker-091520-1609-4809-500-32x32.jpg',
#      'sizes': '32x32'}},
#    {'id': 93,
#     'parent': 3,
#     'previous': 92,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 94,
#     'parent': 3,
#     'previous': 93,
#     'tag': 'LINK',
#     'position': 31,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'icon',
#      'href': 'https://mytravelexp.com/wp-content/uploads/2020/09/cropped-onlinelogomaker-091520-1609-4809-500-192x192.jpg',
#      'sizes': '192x192'}},
#    {'id': 95,
#     'parent': 3,
#     'previous': 94,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 96,
#     'parent': 3,
#     'previous': 95,
#     'tag': 'LINK',
#     'position': 32,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'apple-touch-icon',
#      'href': 'https://mytravelexp.com/wp-content/uploads/2020/09/cropped-onlinelogomaker-091520-1609-4809-500-180x180.jpg'}},
#    {'id': 97,
#     'parent': 3,
#     'previous': 96,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 98,
#     'parent': 3,
#     'previous': 97,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 99,
#     'parent': 5,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n'},
#    {'id': 100,
#     'parent': 5,
#     'previous': 99,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)',
#     'hash': '2gzlja7hy',
#     'attributes': {'class': 'hfeed site', 'id': 'page'}},
#    {'id': 101,
#     'parent': 5,
#     'previous': 100,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\n\t'},
#    {'id': 102,
#     'parent': 5,
#     'previous': 101,
#     'tag': 'LINK',
#     'position': 1,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'id': 'so-css-astra-css',
#      'href': 'https://mytravelexp.com/wp-content/uploads/so-css/so-css-astra.css?ver=1600183114',
#      'media': 'all'}},
#    {'id': 103,
#     'parent': 5,
#     'previous': 102,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 104,
#     'parent': 5,
#     'previous': 103,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 105,
#     'parent': 5,
#     'previous': 104,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 106,
#     'parent': 5,
#     'previous': 105,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 107,
#     'parent': 5,
#     'previous': 106,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 108,
#     'parent': 5,
#     'previous': 107,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 109,
#     'parent': 5,
#     'previous': 108,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 110,
#     'parent': 5,
#     'previous': 109,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 111,
#     'parent': 5,
#     'previous': 110,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 112,
#     'parent': 5,
#     'previous': 111,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 113,
#     'parent': 5,
#     'previous': 112,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 114,
#     'parent': 5,
#     'previous': 113,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 115,
#     'parent': 5,
#     'previous': 114,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 116,
#     'parent': 5,
#     'previous': 115,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 117,
#     'parent': 5,
#     'previous': 116,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 118,
#     'parent': 5,
#     'previous': 117,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 119,
#     'parent': 5,
#     'previous': 118,
#     'tag': 'SPAN',
#     'position': None,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>SPAN.elementor-screen-only',
#     'hash': '8qw148vtc',
#     'attributes': {'id': 'elementor-device-mode',
#      'class': 'elementor-screen-only'}},
#    {'id': 120,
#     'parent': 5,
#     'previous': 119,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 121,
#     'parent': 5,
#     'previous': 120,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 122,
#     'parent': 5,
#     'previous': 121,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 123,
#     'parent': 5,
#     'previous': 122,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 124,
#     'parent': 5,
#     'previous': 123,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 125,
#     'parent': 5,
#     'previous': 124,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t\t'},
#    {'id': 126,
#     'parent': 5,
#     'previous': 125,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t\t\n\t\n\n'},
#    {'id': 127,
#     'parent': 12,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': 'Budget Travel Archives - My Travel Exp'},
#    {'id': 128,
#     'parent': 100,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 129,
#     'parent': 100,
#     'previous': 128,
#     'tag': 'A',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>A.skip-link.screen-reader-text:nth-of-type(1)',
#     'hash': '27ci83qy4',
#     'attributes': {'class': 'skip-link screen-reader-text',
#      'href': '#content'}},
#    {'id': 130,
#     'parent': 100,
#     'previous': 129,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\n\t\n\t\t'},
#    {'id': 131,
#     'parent': 100,
#     'previous': 130,
#     'tag': 'HEADER',
#     'position': None,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>HEADER.site-header.ast-primary-submenu-animation-fade.header-main-layout-1.ast-primary-menu-enabled.ast-logo-title-inline.ast-hide-custom-menu-mobile.ast-menu-toggle-icon.ast-mobile-header-inline',
#     'hash': '8jsbvawed',
#     'attributes': {'class': 'site-header ast-primary-submenu-animation-fade header-main-layout-1 ast-primary-menu-enabled ast-logo-title-inline ast-hide-custom-menu-mobile ast-menu-toggle-icon ast-mobile-header-inline',
#      'id': 'masthead',
#      'itemtype': 'https://schema.org/WPHeader',
#      'itemscope': 'itemscope',
#      'itemid': '#masthead'}},
#    {'id': 132,
#     'parent': 100,
#     'previous': 131,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\t\n\t\n\t\n\t'},
#    {'id': 133,
#     'parent': 100,
#     'previous': 132,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>DIV.site-content:nth-of-type(1)',
#     'hash': '4acrx0wgp',
#     'attributes': {'id': 'content', 'class': 'site-content'}},
#    {'id': 134,
#     'parent': 100,
#     'previous': 133,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\t\n\t\t\n\t\t\t\t'},
#    {'id': 135,
#     'parent': 100,
#     'previous': 134,
#     'tag': 'FOOTER',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>FOOTER:nth-of-type(1)',
#     'hash': '6gwy52byo',
#     'attributes': {'itemtype': 'https://schema.org/WPFooter',
#      'itemscope': 'itemscope',
#      'id': 'colophon',
#      'role': 'contentinfo'}},
#    {'id': 136,
#     'parent': 100,
#     'previous': 135,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\n\t\t\n\t'},
#    {'id': 137,
#     'parent': 129,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': 'Skip to content'},
#    {'id': 138,
#     'parent': 131,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\t\t\n\t\t\t\n'},
#    {'id': 139,
#     'parent': 131,
#     'previous': 138,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>HEADER.site-header.ast-primary-submenu-animation-fade.header-main-layout-1.ast-primary-menu-enabled.ast-logo-title-inline.ast-hide-custom-menu-mobile.ast-menu-toggle-icon.ast-mobile-header-inline>DIV.main-header-bar-wrap:nth-of-type(1)',
#     'hash': 'ud46bo9z',
#     'attributes': {'class': 'main-header-bar-wrap'}},
#    {'id': 140,
#     'parent': 131,
#     'previous': 139,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': ' '},
#    {'id': 141,
#     'parent': 131,
#     'previous': 140,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\t\t\n\t\t'},
#    {'id': 142,
#     'parent': 133,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\t'},
#    {'id': 143,
#     'parent': 133,
#     'previous': 142,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>DIV.site-content:nth-of-type(1)>DIV.ast-container:nth-of-type(1)',
#     'hash': '7qj69eiuh',
#     'attributes': {'class': 'ast-container'}},
#    {'id': 144,
#     'parent': 133,
#     'previous': 143,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': ' '},
#    {'id': 145,
#     'parent': 133,
#     'previous': 144,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\t'},
#    {'id': 146,
#     'parent': 135,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t\t'},
#    {'id': 147,
#     'parent': 135,
#     'previous': 146,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>FOOTER:nth-of-type(1)>DIV.footer-width-fixer:nth-of-type(1)',
#     'hash': '8ro9uuaih',
#     'attributes': {'class': 'footer-width-fixer'}},
#    {'id': 148,
#     'parent': 135,
#     'previous': 147,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\t\t'},
#    {'id': 149,
#     'parent': 139,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 150,
#     'parent': 139,
#     'previous': 149,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>HEADER.site-header.ast-primary-submenu-animation-fade.header-main-layout-1.ast-primary-menu-enabled.ast-logo-title-inline.ast-hide-custom-menu-mobile.ast-menu-toggle-icon.ast-mobile-header-inline>DIV.main-header-bar-wrap:nth-of-type(1)>DIV.main-header-bar:nth-of-type(1)',
#     'hash': '7icux1nvu',
#     'attributes': {'class': 'main-header-bar'}},
#    {'id': 151,
#     'parent': 139,
#     'previous': 150,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': ' '},
#    {'id': 152,
#     'parent': 139,
#     'previous': 151,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 153,
#     'parent': 143,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\t\n\n\t'},
#    {'id': 154,
#     'parent': 143,
#     'previous': 153,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>DIV.site-content:nth-of-type(1)>DIV.ast-container:nth-of-type(1)>DIV.content-area.primary:nth-of-type(1)',
#     'hash': '2a1cq6m5i',
#     'attributes': {'id': 'primary', 'class': 'content-area primary'}},
#    {'id': 155,
#     'parent': 143,
#     'previous': 154,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\n\t'},
#    {'id': 156,
#     'parent': 143,
#     'previous': 155,
#     'tag': 'DIV',
#     'position': 2,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>DIV.site-content:nth-of-type(1)>DIV.ast-container:nth-of-type(1)>DIV.widget-area.secondary:nth-of-type(2)',
#     'hash': '6k5lj9ua6',
#     'attributes': {'class': 'widget-area secondary',
#      'id': 'secondary',
#      'role': 'complementary',
#      'itemtype': 'https://schema.org/WPSideBar',
#      'itemscope': 'itemscope'}},
#    {'id': 157,
#     'parent': 143,
#     'previous': 156,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\n\t\t\t\n\t\t\t'},
#    {'id': 158,
#     'parent': 147,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\t\t'},
#    {'id': 159,
#     'parent': 147,
#     'previous': 158,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>FOOTER:nth-of-type(1)>DIV.footer-width-fixer:nth-of-type(1)>DIV.elementor.elementor-162:nth-of-type(1)',
#     'hash': '4ofekysjf',
#     'attributes': {'data-elementor-type': 'wp-post',
#      'data-elementor-id': '162',
#      'class': 'elementor elementor-162',
#      'data-elementor-settings': '[]'}},
#    {'id': 160,
#     'parent': 147,
#     'previous': 159,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t'},
#    {'id': 161,
#     'parent': 150,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t\t\t'},
#    {'id': 162,
#     'parent': 150,
#     'previous': 161,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>HEADER.site-header.ast-primary-submenu-animation-fade.header-main-layout-1.ast-primary-menu-enabled.ast-logo-title-inline.ast-hide-custom-menu-mobile.ast-menu-toggle-icon.ast-mobile-header-inline>DIV.main-header-bar-wrap:nth-of-type(1)>DIV.main-header-bar:nth-of-type(1)>DIV.ast-container:nth-of-type(1)',
#     'hash': '8869rg1hc',
#     'attributes': {'class': 'ast-container'}},
#    {'id': 163,
#     'parent': 150,
#     'previous': 162,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t\t'},
#    {'id': 164,
#     'parent': 154,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\t\n\t\t\n\t\t\t\t'},
#    {'id': 165,
#     'parent': 154,
#     'previous': 164,
#     'tag': 'SECTION',
#     'position': None,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>DIV.site-content:nth-of-type(1)>DIV.ast-container:nth-of-type(1)>DIV.content-area.primary:nth-of-type(1)>SECTION.ast-archive-description',
#     'hash': '4irdyo8n7',
#     'attributes': {'class': 'ast-archive-description'}},
#    {'id': 166,
#     'parent': 154,
#     'previous': 165,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\t\t\t\n\t\t\t\t\t'},
#    {'id': 167,
#     'parent': 154,
#     'previous': 166,
#     'tag': 'MAIN',
#     'position': None,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>DIV.site-content:nth-of-type(1)>DIV.ast-container:nth-of-type(1)>DIV.content-area.primary:nth-of-type(1)>MAIN.site-main',
#     'hash': '5le7vnec0',
#     'attributes': {'id': 'main', 'class': 'site-main'}},
#    {'id': 168,
#     'parent': 154,
#     'previous': 167,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t\t\n\t\t'},
#    {'id': 169,
#     'parent': 154,
#     'previous': 168,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>DIV.site-content:nth-of-type(1)>DIV.ast-container:nth-of-type(1)>DIV.content-area.primary:nth-of-type(1)>DIV.ast-pagination:nth-of-type(1)',
#     'hash': '2pr927h6f',
#     'attributes': {'class': 'ast-pagination'}},
#    {'id': 170,
#     'parent': 154,
#     'previous': 169,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t\n\t'},
#    {'id': 171,
#     'parent': 156,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t'},
#    {'id': 172,
#     'parent': 156,
#     'previous': 171,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>DIV.site-content:nth-of-type(1)>DIV.ast-container:nth-of-type(1)>DIV.widget-area.secondary:nth-of-type(2)>DIV.sidebar-main:nth-of-type(1)',
#     'hash': '70oqm1kn4',
#     'attributes': {'class': 'sidebar-main'}},
#    {'id': 173,
#     'parent': 156,
#     'previous': 172,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n'},
#    {'id': 174,
#     'parent': 159,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t\t\t\t\t'},
#    {'id': 175,
#     'parent': 159,
#     'previous': 174,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>FOOTER:nth-of-type(1)>DIV.footer-width-fixer:nth-of-type(1)>DIV.elementor.elementor-162:nth-of-type(1)>DIV.elementor-inner:nth-of-type(1)',
#     'hash': '19lsuqxzt',
#     'attributes': {'class': 'elementor-inner'}},
#    {'id': 176,
#     'parent': 159,
#     'previous': 175,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\t\t\t\t\t'},
#    {'id': 177,
#     'parent': 162,
#     'previous': None,
#     'tag': '*T',
#     'position': None,
#     'selector': None,
#     'hash': None,
#     'value': '\n\n\t\t\t'},
#    {'id': 178,
#     'parent': 162,
#     'previous': 177,
#     'tag': 'DIV',
#     'position': 1,
# ...
#     'hash': '72znqlmy4',
#     'attributes': {'data-tn-originlogtype': 'vegetaSectionImpression',
#      'data-tn-olth': '2638f921292646843139274add3e8d57',
#      'data-tn-originlogid': 'defaultLogId',
#      'data-tn-application': 'vegeta'}},
#    {'id': 685,
#     'parent': 684,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(2)>DIV.resolved:nth-of-type(1)>*S:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)',
#     'hash': '78zqnb9hw'},
#    {'id': 686,
#     'parent': 685,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(2)>DIV.resolved:nth-of-type(1)>*S:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)>DIV.react-draggable:nth-of-type(1)',
#     'hash': '3oiumfi3b',
#     'attributes': {'class': 'react-draggable',
#      'style': 'touch-action: none; margin-left: calc(100vw - 470px); margin-top: 40px; width: 440px; transform: translate(0px, 0px);'}},
#    {'id': 687,
#     'parent': 5,
#     'previous': 126,
#     'tag': 'DIV',
#     'position': 3,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)',
#     'hash': '2a0oac6gh',
#     'attributes': {'id': 'i4c-dialogs-container'}},
#    {'id': 688,
#     'parent': 687,
#     'previous': None,
#     'tag': '*S',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)',
#     'hash': '4eawvz0z5',
#     'attributes': {'style': ''}},
#    {'id': 689,
#     'parent': 688,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(1)',
#     'hash': '83lni9kg9'},
#    {'id': 690,
#     'parent': 688,
#     'previous': 689,
#     'tag': 'DIV',
#     'position': 2,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)',
#     'hash': '83lni8tnc'},
#    {'id': 691,
#     'parent': 689,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)',
#     'hash': '2julo7osn',
#     'attributes': {'data-reactroot': ''}},
#    {'id': 692,
#     'parent': 690,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(1)',
#     'hash': '2o9pkakl4'},
#    {'id': 693,
#     'parent': 690,
#     'previous': 692,
#     'tag': 'DIV',
#     'position': 2,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(2)',
#     'hash': '2o9pkakl1'},
#    {'id': 694,
#     'parent': 690,
#     'previous': 693,
#     'tag': 'DIV',
#     'position': 3,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(3)',
#     'hash': '2o9pkakl2'},
#    {'id': 695,
#     'parent': 691,
#     'previous': None,
#     'tag': 'LINK',
#     'position': 1,
#     'selector': None,
#     'hash': None,
#     'attributes': {'rel': 'stylesheet',
#      'href': 'chrome-extension://onimolfnbjjikjiialpfahffkjjgdgkh/content-detached.css'}},
#    {'id': 696,
#     'parent': 691,
#     'previous': 695,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)',
#     'hash': '7ihsejlsn',
#     'attributes': {'data-tn-originlogtype': 'vegetaSectionImpression',
#      'data-tn-olth': '2638f921292646843139274add3e8d57',
#      'data-tn-originlogid': 'defaultLogId',
#      'data-tn-application': 'vegeta'}},
#    {'id': 697,
#     'parent': 692,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(1)>DIV:nth-of-type(1)',
#     'hash': '8nnjo29eg',
#     'attributes': {'data-reactroot': '',
#      'data-tn-section': 'getStartedView',
#      'style': 'position: fixed; box-sizing: border-box; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); z-index: 1500; top: 0px; left: -10000px; width: 100%; height: 100%; transition: left 0ms cubic-bezier(0.23, 1, 0.32, 1) 450ms;'}},
#    {'id': 698,
#     'parent': 693,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(2)>DIV:nth-of-type(1)',
#     'hash': '8nnpc9mxn',
#     'attributes': {'data-reactroot': '',
#      'style': 'position: fixed; box-sizing: border-box; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); z-index: 1500; top: 0px; left: -10000px; width: 100%; height: 100%; transition: left 0ms cubic-bezier(0.23, 1, 0.32, 1) 450ms;'}},
#    {'id': 699,
#     'parent': 694,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(3)>DIV:nth-of-type(1)',
#     'hash': '8no78snbu',
#     'attributes': {'data-reactroot': '',
#      'style': 'position: fixed; box-sizing: border-box; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); z-index: 1500; top: 0px; left: -10000px; width: 100%; height: 100%; transition: left 0ms cubic-bezier(0.23, 1, 0.32, 1) 450ms;'}},
#    {'id': 700,
#     'parent': 696,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)',
#     'hash': '6vjdzoclr'},
#    {'id': 701,
#     'parent': 696,
#     'previous': 700,
#     'tag': 'DIV',
#     'position': 2,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(2)',
#     'hash': '6vjdzoclo'},
#    {'id': 702,
#     'parent': 697,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(1)',
#     'hash': '18951gxb4'},
#    {'id': 703,
#     'parent': 697,
#     'previous': 702,
#     'tag': 'DIV',
#     'position': 2,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(1)>DIV:nth-of-type(1)>DIV:nth-of-type(2)',
#     'hash': '18951gxb7',
#     'attributes': {'style': 'position: fixed; height: 100%; width: 100%; top: 0px; left: -100%; opacity: 0; background-color: rgba(0, 0, 0, 0.54); -webkit-tap-highlight-color: rgba(0, 0, 0, 0); will-change: opacity; transform: translateZ(0px); transition: left 0ms cubic-bezier(0.23, 1, 0.32, 1) 400ms, opacity 400ms cubic-bezier(0.23, 1, 0.32, 1) 0ms; z-index: 1400;'}},
#    {'id': 704,
#     'parent': 698,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(2)>DIV:nth-of-type(1)>DIV:nth-of-type(1)',
#     'hash': '1894raghv'},
#    {'id': 705,
#     'parent': 698,
#     'previous': 704,
#     'tag': 'DIV',
#     'position': 2,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(2)>DIV:nth-of-type(1)>DIV:nth-of-type(2)',
#     'hash': '1894raghs',
#     'attributes': {'style': 'position: fixed; height: 100%; width: 100%; top: 0px; left: -100%; opacity: 0; background-color: rgba(0, 0, 0, 0.54); -webkit-tap-highlight-color: rgba(0, 0, 0, 0); will-change: opacity; transform: translateZ(0px); transition: left 0ms cubic-bezier(0.23, 1, 0.32, 1) 400ms, opacity 400ms cubic-bezier(0.23, 1, 0.32, 1) 0ms; z-index: 1400;'}},
#    {'id': 706,
#     'parent': 699,
#     'previous': None,
#     'tag': 'DIV',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(3)>DIV:nth-of-type(1)>DIV:nth-of-type(1)',
#     'hash': '188leo06a'},
#    {'id': 707,
#     'parent': 699,
#     'previous': 706,
#     'tag': 'DIV',
#     'position': 2,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV:nth-of-type(3)>*S:nth-of-type(1)>DIV:nth-of-type(2)>DIV:nth-of-type(3)>DIV:nth-of-type(1)>DIV:nth-of-type(2)',
#     'hash': '188leo069',
#     'attributes': {'style': 'position: fixed; height: 100%; width: 100%; top: 0px; left: -100%; opacity: 0; background-color: rgba(0, 0, 0, 0.54); -webkit-tap-highlight-color: rgba(0, 0, 0, 0); will-change: opacity; transform: translateZ(0px); transition: left 0ms cubic-bezier(0.23, 1, 0.32, 1) 400ms, opacity 400ms cubic-bezier(0.23, 1, 0.32, 1) 0ms; z-index: 1400;'}}]},
#  {'time': 665,
#   'event': 6,
#   'data': [{'id': 604,
#     'parent': 578,
#     'previous': None,
#     'tag': 'IFRAME',
#     'position': 1,
#     'selector': 'HTML>BODY.archive.category.category-budget-travel.category-82.ehf-footer.ehf-template-astra.ehf-stylesheet-astra.ast-desktop.ast-separate-container.ast-right-sidebar.astra-2.5.5.ast-header-custom-item-inside.ast-inherit-site-logo-transparent.elementor-default.elementor-kit-4>DIV.hfeed.site:nth-of-type(1)>FOOTER:nth-of-type(1)>DIV.footer-width-fixer:nth-of-type(1)>DIV.elementor.elementor-162:nth-of-type(1)>DIV.elementor-inner:nth-of-type(1)>DIV.elementor-section-wrap:nth-of-type(1)>SECTION.elementor-section.elementor-top-section.elementor-element.elementor-element-a9c56a3.elementor-section-content-middle.elementor-section-boxed.elementor-section-height-default.elementor-section-height-default>DIV.elementor-container.elementor-column-gap-no:nth-of-type(2)>DIV.elementor-row:nth-of-type(1)>DIV.elementor-column.elementor-col-50.elementor-top-column.elementor-element.elementor-element-0bfa0d6:nth-of-type(2)>DIV.elementor-column-wrap.elementor-element-populated:nth-of-type(1)>DIV.elementor-widget-wrap:nth-of-type(1)>DIV.elementor-element.elementor-element-1704b03.elementor-widget.elementor-widget-google_maps:nth-of-type(2)>DIV.elementor-widget-container:nth-of-type(1)>DIV.elementor-custom-embed:nth-of-type(1)>IFRAME:nth-of-type(1)',
#     'hash': '4jw0u9yf2',
#     'attributes': {'frameborder': '0',
#      'scrolling': 'no',
#      'marginheight': '0',
#      'marginwidth': '0',
#      'src': 'https://maps.google.com/maps?q=whitefield%20&t=m&z=15&output=embed&iwloc=near',
#      'aria-label': 'whitefield '}}]}]

# %% [markdown]
# ### Upgrade

# %%
a.upgrade
# Out:
# 197    NaN
# 198    NaN
# 199    NaN
# 200    NaN
# Name: upgrade, dtype: object

# %% [markdown]
# ### Selection

# %%
a.selection
# Out:
# 197    NaN
# 198    NaN
# 199    NaN
# 200    NaN
# Name: selection, dtype: object

# %% [markdown]
# ### Timeline

# %%
a.timeline
# Out:
# 197    NaN
# 198    NaN
# 199    NaN
# 200    NaN
# Name: timeline, dtype: object
